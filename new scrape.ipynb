# %% [markdown]
# # Web Scraping

# %% [markdown]
# # 2012

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2012/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2012.xlsx", index=False)
# Out:
# Error getting version of chromedriver 115. Retrying with chromedriver 114 (attempt 1/5)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[1], line 28
#      25 options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode
#      27 # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
# ---> 28 driver = webdriver.Chrome(service=service, options=options)
#      31 url="https://www.bailii.org/ew/cases/EWCA/Civ/2012/{}.html".format(i)
#      32 driver.get(url)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:49, in WebDriver.__init__(self, options, service, keep_alive)
#      45 self.keep_alive = keep_alive
#      47 self.service.path = DriverFinder.get_path(self.service, self.options)
# ---> 49 super().__init__(
#      50     DesiredCapabilities.CHROME["browserName"],
#      51     "goog",
# ...

# %% [markdown]
# # 2013

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2013/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2013.xlsx", index=False)

# %% [markdown]
# # 2014

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2014/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2014.xlsx", index=False)

# %% [markdown]
# # 2015

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2015/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2015.xlsx", index=False)

# %% [markdown]
# # 2016

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2016/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2016.xlsx", index=False)

# %% [markdown]
# # 2017

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2012/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2017.xlsx", index=False)

# %% [markdown]
# # 2018

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2018/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2018.xlsx", index=False)

# %% [markdown]
# # 2019

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2019/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2019.xlsx", index=False)

# %% [markdown]
# # 2020

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2020/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2020.xlsx", index=False)

# %% [markdown]
# # 2021

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2021/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2021.xlsx", index=False)

# %% [markdown]
# # 2022

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

i=1
blog_info_list=[]
while i<=1000:

        # Specify the path to the ChromeDriver executable
        path = "C:/Users/pc/Documents/start/chromedriver.exe"
        # Create a Service object with the executable path
        service = Service(path)

        # Create ChromeOptions object instead of chrome_options
        options = webdriver.ChromeOptions()

        # Add any desired options to the ChromeOptions object
        options.add_argument("--no-sandbox")  # Example: Run Chrome in headless mode

        # Pass the Service object and ChromeOptions object to the webdriver.Chrome() constructor
        driver = webdriver.Chrome(service=service, options=options)


        url="https://www.bailii.org/ew/cases/EWCA/Civ/2022/{}.html".format(i)
        driver.get(url)

        try:
            judge=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")
            if len(judge)==3:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[2]

            if len(judge)==2:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[1]
                judge3="none"

            if len(judge)==1:
                judge1=driver.find_element(By.XPATH, "/html/body/center[2]/p[2]/b/panel").text.replace('and\n', '').split("\n")[0]
                judge2="none"
                judge3="none"
        except:
            judge1,judge2, judge3= np.nan, np.nan, np.nan

        try:
            case_no=driver.find_element(By.XPATH, "/html/body/table/tbody/tr[2]/td[3]/font/casenum").text[8:].strip()
        except:
            case_no = np.nan

        try:
            date=driver.find_element(By.XPATH, "/html/body/p[6]/table/tbody/tr[2]").text
        except:
            date= np.nan
        try:
            appellant=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr/td[2]").text
        except:
            appellant= np.nan

        try:
            Respondent=driver.find_element(By.XPATH, "/html/body/center[2]/parties/table/tbody/tr[3]/td[2]/b").text
        except:
            Respondent= np.nan
        try:
            length_of_judgment=test=len(driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", " "))
        except:
            length_of_judgment= np.nan

        try:
            full_judgement=driver.find_element(By.XPATH, "/html/body/ol").text.replace("\n", '')

        except:
            full_judgement=np.nan

        try:
            if len(judge)==3:
                j3 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-1]
                j2 = driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3]
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-8:-4])

            elif len(judge)==1:
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-3:])
                j2 = "none"
                j3= "none"
            elif len(judge)==2:
                j3 = "none"
                j2 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-2:])
                j1 = " ".join(driver.find_element(By.XPATH, "/html/body/ol").text.split("\n")[-5:-3])
                
        except:
            j1,j2,j3 = np.nan, np.nan, np.nan
        try:
            appeal_from= "".join(driver.find_element(By.XPATH, "/html/body/p[5]").text.split("\n")[1:]).replace("ON APPEAL FROM", "")

        except:
            np.nan

        blog_dict = {
            "case number": case_no,
                "Date of the judgement": date,
                "judge one": judge1, 
                "judge two": judge2,                    
                "judge3 three": judge3,                    
                "Appellant": appellant,
                "Respondent": Respondent,
                "appeal from": appeal_from,
                "judge one conclusion":  j1,
                "judge two conclusion":  j2,
                "judge three conclusion":  j3,
                "length of judgement": length_of_judgment,
                "full judgement": full_judgement,

            }

        blog_info_list.append(blog_dict)
        i+=1
dataframe = pd.DataFrame(blog_info_list)
dataframe.dropna(inplace=True)
dataframe.to_excel("2022.xlsx", index=False)
